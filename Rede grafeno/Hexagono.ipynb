# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import qiskit_metal as metal
from qiskit_metal import Dict, designs, MetalGUI
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
import numpy as np
from collections import OrderedDict
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
from qiskit_metal.qlibrary.tlines.framed_path import RouteFramed
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.lumped.cap_n_interdigital import CapNInterdigital

# %%
design = designs.DesignPlanar(overwrite_enabled=True)

# %%
gui = MetalGUI(design)
design.variables['cpw_width']='20um'
design.variables['cpw_gap']='12um'

# %% [markdown]
# # Hexagono

# %%
#ressonador 1
px = 0
py = 0

otg1 = OpenToGround(design, 'OTG1', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg2 = OpenToGround(design, 'OTG2', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py+1])
anchors[1] = np.array([px+0,py+3.01])
anchors[2] = np.array([px+0.6,py+1])

res1 = RouteAnchors(design, 'RES1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG1',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG2',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))
#########################################
#ressonador 2
px = 2.37
py = -0.07

otg3 = OpenToGround(design, 'OTG3', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

cap4 = CapNInterdigital(design, 'CAP4', options = Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='90',
    north_width='20um',
    north_gap='12um',
    south_width='20um',
    south_gap='12um',
    cap_width='5um',
    cap_gap='6um',
    cap_gap_ground='12um',
    finger_length='55um',
    finger_count='3',
    cap_distance='1um'
))

otg4 = OpenToGround(design, 'OTG4', options=Dict(
    pos_x=f'{px+3}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py-1])
anchors[1] = np.array([px+0,py-3.01])
anchors[2] = np.array([px+0.6,py-1])

res2 = RouteAnchors(design, 'RES2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG3',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'CAP4',
            pin = 'north_end'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

line2 = RouteStraight(design, 'LINE2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'CAP4',
            pin = 'south_end'
        ),
        end_pin = Dict(
            component = 'OTG4',
            pin = 'open'
        )
    )
))

#########################################
#ressonador 3
px = -2.37
py = -0.07

cap5 = CapNInterdigital(design, 'CAP5', options = Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='-90',
    north_width='20um',
    north_gap='12um',
    south_width='20um',
    south_gap='12um',
    cap_width='5um',
    cap_gap='6um',
    cap_gap_ground='12um',
    finger_length='55um',
    finger_count='3',
    cap_distance='1um'
))

otg5 = OpenToGround(design, 'OTG5', options=Dict(
    pos_x=f'{px-3}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg6 = OpenToGround(design, 'OTG6', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py-1])
anchors[1] = np.array([px+0,py-3.01])
anchors[2] = np.array([px+0.6,py-1])

res3 = RouteAnchors(design, 'RES3', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'CAP5',
            pin = 'north_end'
        ),
        end_pin = Dict(
            component = 'OTG6',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

line3 = RouteStraight(design, 'LINE3', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'CAP5',
            pin = 'south_end'
        ),
        end_pin = Dict(
            component = 'OTG5',
            pin = 'open'
        )
    )
))

#########################################
#ressonador 4
px = 2.37
py = -6.16

otg7 = OpenToGround(design, 'OTG7', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

cap8 = CapNInterdigital(design, 'CAP8', options = Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='90',
    north_width='20um',
    north_gap='12um',
    south_width='20um',
    south_gap='12um',
    cap_width='5um',
    cap_gap='6um',
    cap_gap_ground='12um',
    finger_length='55um',
    finger_count='3',
    cap_distance='1um'
))

otg8 = OpenToGround(design, 'OTG8', options=Dict(
    pos_x=f'{px+3}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py+1])
anchors[1] = np.array([px+0,py+3.01])
anchors[2] = np.array([px+0.6,py+1])

res4 = RouteAnchors(design, 'RES4', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG7',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'CAP8',
            pin = 'north_end'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

line4 = RouteStraight(design, 'LINE4', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG8',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'CAP8',
            pin = 'south_end'
        )
    )
))

#########################################
#ressonador 5
px = -2.37
py = -6.16

cap9 = CapNInterdigital(design, 'CAP9', options = Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='-90',
    north_width='20um',
    north_gap='12um',
    south_width='20um',
    south_gap='12um',
    cap_width='5um',
    cap_gap='6um',
    cap_gap_ground='12um',
    finger_length='55um',
    finger_count='3',
    cap_distance='1um'
))

otg9 = OpenToGround(design, 'OTG9', options=Dict(
    pos_x=f'{px-3}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg10 = OpenToGround(design, 'OTG10', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py+1])
anchors[1] = np.array([px+0,py+3.01])
anchors[2] = np.array([px+0.6,py+1])

res5 = RouteAnchors(design, 'RES5', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'CAP9',
            pin = 'north_end'
        ),
        end_pin = Dict(
            component = 'OTG10',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

line5 = RouteStraight(design, 'LINE5', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG9',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'CAP9',
            pin = 'south_end'
        )
    )
))

#########################################
#ressonador 6
px = 0
py = -6.23

otg11 = OpenToGround(design, 'OTG11', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg12 = OpenToGround(design, 'OTG12', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py-1])
anchors[1] = np.array([px+0,py-3.01])
anchors[2] = np.array([px+0.6,py-1])

res6 = RouteAnchors(design, 'RES6', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG11',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG12',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# # Um ressonador

# %%
design.delete_all_components()

# %%
px1 = 0
py1 = 0

otg1 = OpenToGround(design, 'OTG1', options=Dict(
    pos_x=f'{px1-1.6}mm',
    pos_y=f'{py1}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg2 = OpenToGround(design, 'OTG2', options=Dict(
    pos_x=f'{px1+1.6}mm',
    pos_y=f'{py1}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px1-0.6,py1+1])
anchors[1] = np.array([px1+0,py1+3.01])
anchors[2] = np.array([px1+0.6,py1+1])

res1 = RouteAnchors(design, 'RES1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG1',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG2',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

otg3 = OpenToGround(design, 'OTG3', options=Dict(
    pos_x='0.77mm',
    pos_y='-0.07mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg4 = OpenToGround(design, 'OTG4', options=Dict(
    pos_x='2.5mm',
    pos_y='-0.07mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg5 = OpenToGround(design, 'OTG5', options=Dict(
    pos_x='-0.77mm',
    pos_y='-0.07mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg6 = OpenToGround(design, 'OTG6', options=Dict(
    pos_x='-2.5mm',
    pos_y='-0.07mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

line1 = RouteStraight(design, 'LINE1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG3',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG4',
            pin = 'open'
        )
    ),
))

line2 = RouteStraight(design, 'LINE2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG5',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG6',
            pin = 'open'
        )
    ),
))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# # Hexagono versão 2

# %%
design.delete_all_components()
# Out:
# Logger issue: Internal C++ object (QTextEditLogger) already deleted.

# %%
#ressonador 1
px1 = 0
py1 = 0

otg1 = OpenToGround(design, 'OTG1', options=Dict(
    pos_x=f'{px1-1.6}mm',
    pos_y=f'{py1}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg2 = OpenToGround(design, 'OTG2', options=Dict(
    pos_x=f'{px1+1.6}mm',
    pos_y=f'{py1}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px1-0.6,py1+1])
anchors[1] = np.array([px1+0,py1+3.01])
anchors[2] = np.array([px1+0.6,py1+1])

res1 = RouteAnchors(design, 'RES1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG1',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG2',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))
#########################################
#ressonador 2
px2 = 2.37
py2 = -0.07

otg3 = OpenToGround(design, 'OTG3', options=Dict(
    pos_x=f'{px2-1.6}mm',
    pos_y=f'{py2}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg4 = OpenToGround(design, 'OTG4', options=Dict(
    pos_x=f'{px2+1.6}mm',
    pos_y=f'{py2}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px2-0.6,py2-1])
anchors[1] = np.array([px2+0,py2-3.01])
anchors[2] = np.array([px2+0.6,py2-1])

res2 = RouteAnchors(design, 'RES2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG3',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG4',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))


#########################################
#ressonador 3
px3 = -2.37
py3 = -0.07

otg5 = OpenToGround(design, 'OTG5', options=Dict(
    pos_x=f'{px3-1.6}mm',
    pos_y=f'{py3}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg6 = OpenToGround(design, 'OTG6', options=Dict(
    pos_x=f'{px3+1.6}mm',
    pos_y=f'{py3}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px3-0.6,py3-1])
anchors[1] = np.array([px3+0,py3-3.01])
anchors[2] = np.array([px3+0.6,py3-1])

res3 = RouteAnchors(design, 'RES3', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG5',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG6',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

#########################################
#ressonador 4
px4 = 2.37
py4 = -6.16

otg7 = OpenToGround(design, 'OTG7', options=Dict(
    pos_x=f'{px4-1.6}mm',
    pos_y=f'{py4}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg8 = OpenToGround(design, 'OTG8', options=Dict(
    pos_x=f'{px4+1.6}mm',
    pos_y=f'{py4}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px4-0.6,py4+1])
anchors[1] = np.array([px4+0,py4+3.01])
anchors[2] = np.array([px4+0.6,py4+1])

res4 = RouteAnchors(design, 'RES4', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG7',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG8',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

#########################################
#ressonador 5
px5 = -2.37
py5 = -6.16

otg9 = OpenToGround(design, 'OTG9', options=Dict(
    pos_x=f'{px5-1.6}mm',
    pos_y=f'{py5}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg10 = OpenToGround(design, 'OTG10', options=Dict(
    pos_x=f'{px5+1.6}mm',
    pos_y=f'{py5}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px5-0.6,py5+1])
anchors[1] = np.array([px5+0,py5+3.01])
anchors[2] = np.array([px5+0.6,py5+1])

res5 = RouteAnchors(design, 'RES5', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG9',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG10',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

#########################################
#ressonador 6
px6 = 0
py6 = -6.23

otg11 = OpenToGround(design, 'OTG11', options=Dict(
    pos_x=f'{px6-1.6}mm',
    pos_y=f'{py6}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg12 = OpenToGround(design, 'OTG12', options=Dict(
    pos_x=f'{px6+1.6}mm',
    pos_y=f'{py6}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px6-0.6,py6-1])
anchors[1] = np.array([px6+0,py6-3.01])
anchors[2] = np.array([px6+0.6,py6-1])

res6 = RouteAnchors(design, 'RES6', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG11',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG12',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

# linha 1
pad1 = LaunchpadWirebond(design, 'PAD1', options=Dict(
    pos_x=f'{px1-0.425}mm',
    pos_y='4.5mm',
    orientation='-90',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

pad2 = LaunchpadWirebond(design, 'PAD2', options=Dict(
    pos_x=f'{px1+0.425}mm',
    pos_y='4.5mm',
    orientation='-90',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

from collections import OrderedDict
anchors = OrderedDict()
#anchors[0] = np.array([px1-0.425,py1+3.01+0.5])
anchors[0] = np.array([px1,py1+3.01+0.07])
#anchors[1] = np.array([px1+0.425,py1+3.01+0.5])

line1 = RouteAnchors(design, 'LINE1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'PAD1',
            pin = 'tie'
        ),
        end_pin = Dict(
            component = 'PAD2',
            pin = 'tie'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='1mm', end_straight='1mm'),
    total_length='8.5mm',
    fillet='200um',
    hfss_wire_bonds = False
))

# linha 6
pad3 = LaunchpadWirebond(design, 'PAD3', options=Dict(
    pos_x=f'{px6-0.425}mm',
    pos_y=f'{py6-3.01-1.5}mm',
    orientation='90',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

pad4 = LaunchpadWirebond(design, 'PAD4', options=Dict(
    pos_x=f'{px6+0.425}mm',
    pos_y=f'{py6-3.01-1.5}mm',
    orientation='90',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

from collections import OrderedDict
anchors = OrderedDict()
#anchors[0] = np.array([px6-0.425,py6-3.01-0.5])
anchors[0] = np.array([px6,py6-3.01-0.07])
#anchors[1] = np.array([px6+0.425,py6-3.01-0.5])

line6 = RouteAnchors(design, 'LINE6', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'PAD3',
            pin = 'tie'
        ),
        end_pin = Dict(
            component = 'PAD4',
            pin = 'tie'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='1mm', end_straight='1mm'),
    total_length='8.5mm',
    fillet='200um',
    hfss_wire_bonds = False
))

# linha 2
otg13 = OpenToGround(design, 'OTG13', options=Dict(
    pos_x=f'{px2+1.6-0.83}mm',
    pos_y=f'{py2+0.07}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

pad5 = LaunchpadWirebond(design, 'PAD5', options=Dict(
    pos_x=f'{px2+1.6+1}mm',
    pos_y=f'{py2+0.07}mm',
    orientation='180',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

line2 = RouteStraight(design, 'LINE2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG13',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD5',
            pin = 'tie'
        )
    )
))

# linha 3
otg14 = OpenToGround(design, 'OTG14', options=Dict(
    pos_x=f'{px3-1.6+0.83}mm',
    pos_y=f'{py3+0.07}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

pad6 = LaunchpadWirebond(design, 'PAD6', options=Dict(
    pos_x=f'{px3-1.6-1}mm',
    pos_y=f'{py3+0.07}mm',
    orientation='0',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

line3 = RouteStraight(design, 'LINE3', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG14',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD6',
            pin = 'tie'
        )
    )
))

# linha 4
otg15 = OpenToGround(design, 'OTG15', options=Dict(
    pos_x=f'{px4+1.6-0.83}mm',
    pos_y=f'{py4-0.07}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

pad7 = LaunchpadWirebond(design, 'PAD7', options=Dict(
    pos_x=f'{px4+1.6+1}mm',
    pos_y=f'{py4-0.07}mm',
    orientation='180',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

line4 = RouteStraight(design, 'LINE4', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG15',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD7',
            pin = 'tie'
        )
    )
))

# linha 5
otg16 = OpenToGround(design, 'OTG16', options=Dict(
    pos_x=f'{px5-1.6+0.83}mm',
    pos_y=f'{py5-0.07}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

pad8 = LaunchpadWirebond(design, 'PAD8', options=Dict(
    pos_x=f'{px5-1.6-1}mm',
    pos_y=f'{py5-0.07}mm',
    orientation='0',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

line5 = RouteStraight(design, 'LINE5', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG16',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD8',
            pin = 'tie'
        )
    )
))


gui.rebuild()
gui.autoscale()

# %% [markdown]
# # Render to GDS

# %%
design.chips.main.size['size_x'] = '25mm'
design.chips.main.size['size_y'] = '25mm'
design.chips.main
# Out:
# {'material': 'silicon',
#  'layer_start': '0',
#  'layer_end': '2048',
#  'size': {'center_x': '0.0mm',
#   'center_y': '0.0mm',
#   'center_z': '0.0mm',
#   'size_x': '25mm',
#   'size_y': '25mm',
#   'size_z': '-750um',
#   'sample_holder_top': '890um',
#   'sample_holder_bottom': '1650um'}}

# %%
design.renderers.gds.export_to_gds('Hexagon lattice.gds')
# Out:
# 03:51PM 30s WARNING [_import_junctions_to_one_cell]: Not able to find file:"../resources/Fake_Junctions.GDS".  Not used to replace junction. Checked directory:"d:\Users\e196203\Desktop\Git Hub\Projeto-Valentina\resources".
# INFO 03:51PM [__del__]: Disconnected from Ansys HFSS
# 1

# %% [markdown]
# # Q3D

# %%
from qiskit_metal import renderers

# %%
ansys = design.renderers.q3d

# %%
ansys.connect_ansys()
# Out:
# INFO 11:24AM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:24AM [load_ansys_project]: 	Opened Ansys App
# INFO 11:24AM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.0
# INFO 11:24AM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/e196203/Documents/Ansoft/
# 	Project:   Sub redes indutivas
# INFO 11:24AM [connect_design]: 	Opened active design
# 	Design:    Capacitancias hexagono [Solution type: Q3D]
# INFO 11:24AM [get_setup]: 	Opened setup `capacitancias`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:24AM [connect]: 	Connected to project "Sub redes indutivas" and design "Capacitancias hexagono" 😀

# %%
ansys.activate_q3d_design('Capacitancias hexagono')
# Out:
# 11:24AM 36s WARNING [activate_q3d_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# INFO 11:24AM [connect_design]: 	Opened active design
# 	Design:    Capacitancias hexagono [Solution type: Q3D]

# %%
ansys.clean_active_design()
ansys.render_design()

# %%
ansys.add_q3d_setup(
    name='capacitancias',
    freq_ghz=13.7,
    min_passes=2,
    max_passes=15,
    percent_error=0.2
)

# %%
ansys.analyze_setup('capacitancias')
# Out:
# INFO 11:54AM [get_setup]: 	Opened setup `capacitancias`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:54AM [analyze]: Analyzing setup capacitancias
# 12:17PM 00s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  CRITICAL: QEventDispatcherWin32::wakeUp: Failed to post a message (Não há cota suficiente para processar este comando.)

# %%
ansys.get_capacitance_matrix()
# Out:
# INFO 12:20PM [get_matrix]: Exporting matrix data to (D:\Users\e196203\AppData\Local\Temp\2\tmpg2ybwqfh.txt, C, , capacitancias:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 13700000000, Maxwell, 1, False
# (                        g_wb  launch_pad_PAD1  launch_pad_PAD3  \
#  g_wb             13510.70075      -1251.36769      -1255.69294
#  launch_pad_PAD1  -1251.36769       1260.48215         -0.00556
#  launch_pad_PAD3  -1255.69294         -0.00556       1264.79161
#  launch_pad_PAD5   -474.12006         -0.01176         -0.00367
#  launch_pad_PAD6   -474.30563         -0.01229         -0.00362
#  launch_pad_PAD7   -474.23284         -0.00369         -0.01175
#  launch_pad_PAD8   -474.07804         -0.00360         -0.01227
#  trace_RES1       -1422.49258         -5.64785         -0.00112
#  trace_RES2       -1422.19494         -0.00473         -0.00216
#  trace_RES3       -1422.60572         -0.00642         -0.00190
#  trace_RES4       -1422.62078         -0.00242         -0.00439
#  trace_RES5       -1423.21671         -0.00098         -0.00738
#  trace_RES6       -1422.77930         -0.00061         -5.66693
#
#                   launch_pad_PAD5  launch_pad_PAD6  launch_pad_PAD7  \
#  g_wb                  -474.12006       -474.30563       -474.23284
#  launch_pad_PAD1         -0.01176         -0.01229         -0.00369
#  launch_pad_PAD3         -0.00367         -0.00362         -0.01175
#  launch_pad_PAD5        481.99135         -0.00136         -0.00718
#  launch_pad_PAD6         -0.00136        482.18691         -0.00189
#  launch_pad_PAD7         -0.00718         -0.00189        482.19399
#  launch_pad_PAD8         -0.00157         -0.00746         -0.00164
#  trace_RES1              -0.00389         -0.00416         -0.00076
#  trace_RES2              -6.42261         -0.00164         -0.00291
#  trace_RES3              -0.00165         -6.43310         -0.00054
#  trace_RES4              -0.00289         -0.00111         -6.43373
#  trace_RES5              -0.00045         -0.00281         -0.00205
#  trace_RES6              -0.00074         -0.00078         -0.00372
#
#                   launch_pad_PAD8  trace_RES1  trace_RES2  trace_RES3  \
#  g_wb                  -474.07804 -1422.49258 -1422.19494 -1422.60572
#  launch_pad_PAD1         -0.00360    -5.64785    -0.00473    -0.00642
#  launch_pad_PAD3         -0.01227    -0.00112    -0.00216    -0.00190
#  launch_pad_PAD5         -0.00157    -0.00389    -6.42261    -0.00165
#  launch_pad_PAD6         -0.00746    -0.00416    -0.00164    -6.43310
#  launch_pad_PAD7         -0.00164    -0.00076    -0.00291    -0.00054
#  launch_pad_PAD8        482.03565    -0.00077    -0.00117    -0.00279
#  trace_RES1              -0.00077  1440.98875    -6.10109    -6.11053
#  trace_RES2              -0.00117    -6.10109  1441.72513    -0.00740
#  trace_RES3              -0.00279    -6.11053    -0.00740  1442.32213
#  trace_RES4              -0.00164    -0.00125    -6.54021    -0.00234
#  trace_RES5              -6.43708    -0.00123    -0.00101    -6.54147
#  trace_RES6              -0.00414    -0.00028    -0.00093    -0.00119
#
#                   trace_RES4  trace_RES5  trace_RES6
#  g_wb            -1422.62078 -1423.21671 -1422.77930
#  launch_pad_PAD1    -0.00242    -0.00098    -0.00061
#  launch_pad_PAD3    -0.00439    -0.00738    -5.66693
#  launch_pad_PAD5    -0.00289    -0.00045    -0.00074
#  launch_pad_PAD6    -0.00111    -0.00281    -0.00078
#  launch_pad_PAD7    -6.43373    -0.00205    -0.00372
#  launch_pad_PAD8    -0.00164    -6.43708    -0.00414
#  trace_RES1         -0.00125    -0.00123    -0.00028
#  trace_RES2         -6.54021    -0.00101    -0.00093
#  trace_RES3         -0.00234    -6.54147    -0.00119
#  trace_RES4       1442.15219    -0.00693    -6.11813
#  trace_RES5         -0.00693  1442.91666    -6.10831
#  trace_RES6         -6.11813    -6.10831  1441.36761  ,
#  'fF')

# %% [markdown]
# # Eigenmode

# %%
ansys.disconnect_ansys()

# %%
ansys = design.renderers.hfss

# %%
ansys.connect_ansys()
# Out:
# INFO 11:58AM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:58AM [load_ansys_project]: 	Opened Ansys App
# INFO 11:58AM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.0
# INFO 11:58AM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/e196203/Documents/Ansoft/
# 	Project:   Sub redes indutivas
# INFO 11:58AM [connect_design]: 	Opened active design
# 	Design:    Capacitancias hexagono [Solution type: Q3D]
# INFO 11:58AM [get_setup]: 	Opened setup `capacitancias`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:58AM [connect]: 	Connected to project "Sub redes indutivas" and design "Capacitancias hexagono" 😀

# %%
ansys.activate_eigenmode_design('um ressonador do hexagono')
# Out:
# 11:58AM 24s WARNING [activate_eigenmode_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# 11:58AM 24s WARNING [activate_ansys_design]: The design_name=um ressonador do hexagono was not in active project.  Designs in active project are:
# ['Capacitancias ressonador notch', 'Capacitancias hexagono', 'S parameter notch resonator1', 'S parameter two resonators', 'sub rede hexagono', 'sub rede 3 indutiva', 'S parameter sub rede hexagono versão 2', 'S parameter other 2 resonators', 'sub rede 3 capacitiva', 'Capacitancias sub rede 3 indutiva', 'S parameter sub rede 3 indutivo', 'two resonators', 'Capacitancias two resonators', 'S parameter 2 notch resonators', 'Capacitancias sub rede 3 capacitiva', 'S parameter sub rede 3 capacitivo', 'S parameter sub rede hexagono', 'notch resonator', 'other two resonators', 'notch 2 resonators'].  A new design will be added to the project.
# INFO 11:58AM [connect_design]: 	Opened active design
# 	Design:    um ressonador do hexagono [Solution type: Eigenmode]
# WARNING 11:58AM [connect_setup]: 	No design setup detected.
# WARNING 11:58AM [connect_setup]: 	Creating eigenmode default setup.
# INFO 11:58AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %%
ansys.clean_active_design()
ansys.render_design(
    selection=['RES1','LINE1','LINE2'],
    open_pins=[('RES1','start'),('RES1','end'),('LINE1','start'),('LINE1','end'),('LINE2','start'),('LINE2','end')]
)

# %%
ansys.add_eigenmode_setup(
    name = 'ressonancias',
    n_modes = 3,
    min_passes = 15,
    max_passes = 20,
    min_converged = 2
)

# %%
ansys.activate_eigenmode_setup('ressonancias')
# Out:
# 12:06PM 05s WARNING [activate_eigenmode_setup]: This method is deprecated. Change your scripts to use activate_ansys_setup()
# INFO 12:06PM [get_setup]: 	Opened setup `ressonancias`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %%
ansys.analyze_setup('ressonancias')
# Out:
# INFO 12:06PM [get_setup]: 	Opened setup `ressonancias`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:06PM [analyze]: Analyzing setup ressonancias

# %%
ansys.pinfo.setup.get_solutions().eigenmodes()
# Out:
# ([6.7585062111, 13.5242479476, 20.311147783], None)

# %%
ansys.plot_ansys_fields('main')
# Out:
# 12:28PM 28s WARNING [plot_ansys_fields]: This method is deprecated. Change your scripts to use plot_fields()

# %% [markdown]
# # Drivenmodal

# %%
ansys = design.renderers.hfss

# %%
ansys.connect_ansys()
# Out:
# INFO 11:27PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:27PM [load_ansys_project]: 	Opened Ansys App
# INFO 11:27PM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.0
# INFO 11:27PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/e196203/Documents/Ansoft/
# 	Project:   Sub redes indutivas
# INFO 11:27PM [connect_design]: 	Opened active design
# 	Design:    notch resonator [Solution type: Eigenmode]
# INFO 11:27PM [get_setup]: 	Opened setup `ressonancias`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 11:27PM [connect]: 	Connected to project "Sub redes indutivas" and design "notch resonator" 😀

# %%
ansys.activate_drivenmodal_design('S parameter sub rede hexagono versão 2')
# Out:
# 11:27PM 18s WARNING [activate_drivenmodal_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# INFO 11:27PM [connect_design]: 	Opened active design
# 	Design:    S parameter sub rede hexagono versão 2 [Solution type: HFSS Hybrid Modal Network]
# 11:27PM 19s WARNING [activate_ansys_design]: The design_name=S parameter sub rede hexagono versão 2 already exists, but it has solution_type==hfss hybrid modal network, which is different from the requested==drivenmodal. If you want a design with solution type==drivenmodal, please change the name requested for your design to one that does not exist. Alternatively, manually modify the solution_type for design S parameter sub rede hexagono versão 2 from the Ansys GUI.

# %%
ansys.clean_active_design()
ansys.render_design(
    selection=['RES1','RES2','RES3','RES4','RES5','RES6','LINE1','LINE2','LINE3','LINE4','LINE5','LINE6'],
    open_pins=[('RES1','start'),('RES1','end'),
               ('RES2','start'),('RES2','end'),
               ('RES3','start'),('RES3','end'),
               ('RES4','start'),('RES4','end'),
               ('RES5','start'),('RES5','end'),
               ('RES6','start'),('RES6','end'),
               ('LINE1','start'),
               ('LINE2','start'),
               ('LINE3','start'),
               ('LINE4','start'),
               ('LINE5','start'),
               ('LINE6','start')],
    port_list=[('LINE1','end',50),('LINE2','end',50),('LINE3','end',50),('LINE4','end',50),('LINE5','end',50),('LINE6','end',50),]
)

# %%
ansys.add_drivenmodal_setup(
    name='Setup',
    min_passes=5,
    max_passes=7,
    min_converged=5,
    max_delta_s=0.02,
    basis_order=-1
)

# %%
ansys.disconnect_ansys()

# %%
gui.main_window.close()
# Out:
# True
