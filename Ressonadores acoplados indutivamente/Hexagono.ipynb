# %%
# %load_ext autoreload
# %autoreload 2

# %%
import qiskit_metal as metal
from qiskit_metal import Dict, designs, MetalGUI
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
import numpy as np
from collections import OrderedDict
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
from qiskit_metal.qlibrary.tlines.framed_path import RouteFramed
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.lumped.cap_n_interdigital import CapNInterdigital

# %%
design = designs.DesignPlanar(overwrite_enabled=True)

# %%
gui = MetalGUI(design)
design.variables['cpw_width']='20um'
design.variables['cpw_gap']='12um'

# %% [markdown]
# # Hexagono

# %%
#ressonador 1
px = 0
py = 0

otg1 = OpenToGround(design, 'OTG1', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg2 = OpenToGround(design, 'OTG2', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py+1])
anchors[1] = np.array([px+0,py+3.01])
anchors[2] = np.array([px+0.6,py+1])

res1 = RouteAnchors(design, 'RES1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG1',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG2',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))
#########################################
#ressonador 2
px = 2.37
py = -0.07

otg3 = OpenToGround(design, 'OTG3', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

cap4 = CapNInterdigital(design, 'CAP4', options = Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='90',
    north_width='20um',
    north_gap='12um',
    south_width='20um',
    south_gap='12um',
    cap_width='5um',
    cap_gap='6um',
    cap_gap_ground='12um',
    finger_length='55um',
    finger_count='3',
    cap_distance='1um'
))

otg4 = OpenToGround(design, 'OTG4', options=Dict(
    pos_x=f'{px+3}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py-1])
anchors[1] = np.array([px+0,py-3.01])
anchors[2] = np.array([px+0.6,py-1])

res2 = RouteAnchors(design, 'RES2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG3',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'CAP4',
            pin = 'north_end'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

line2 = RouteStraight(design, 'LINE2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'CAP4',
            pin = 'south_end'
        ),
        end_pin = Dict(
            component = 'OTG4',
            pin = 'open'
        )
    )
))

#########################################
#ressonador 3
px = -2.37
py = -0.07

cap5 = CapNInterdigital(design, 'CAP5', options = Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='-90',
    north_width='20um',
    north_gap='12um',
    south_width='20um',
    south_gap='12um',
    cap_width='5um',
    cap_gap='6um',
    cap_gap_ground='12um',
    finger_length='55um',
    finger_count='3',
    cap_distance='1um'
))

otg5 = OpenToGround(design, 'OTG5', options=Dict(
    pos_x=f'{px-3}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg6 = OpenToGround(design, 'OTG6', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py-1])
anchors[1] = np.array([px+0,py-3.01])
anchors[2] = np.array([px+0.6,py-1])

res3 = RouteAnchors(design, 'RES3', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'CAP5',
            pin = 'north_end'
        ),
        end_pin = Dict(
            component = 'OTG6',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

line3 = RouteStraight(design, 'LINE3', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'CAP5',
            pin = 'south_end'
        ),
        end_pin = Dict(
            component = 'OTG5',
            pin = 'open'
        )
    )
))

#########################################
#ressonador 4
px = 2.37
py = -6.16

otg7 = OpenToGround(design, 'OTG7', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

cap8 = CapNInterdigital(design, 'CAP8', options = Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='90',
    north_width='20um',
    north_gap='12um',
    south_width='20um',
    south_gap='12um',
    cap_width='5um',
    cap_gap='6um',
    cap_gap_ground='12um',
    finger_length='55um',
    finger_count='3',
    cap_distance='1um'
))

otg8 = OpenToGround(design, 'OTG8', options=Dict(
    pos_x=f'{px+3}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py+1])
anchors[1] = np.array([px+0,py+3.01])
anchors[2] = np.array([px+0.6,py+1])

res4 = RouteAnchors(design, 'RES4', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG7',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'CAP8',
            pin = 'north_end'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

line4 = RouteStraight(design, 'LINE4', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG8',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'CAP8',
            pin = 'south_end'
        )
    )
))

#########################################
#ressonador 5
px = -2.37
py = -6.16

cap9 = CapNInterdigital(design, 'CAP9', options = Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='-90',
    north_width='20um',
    north_gap='12um',
    south_width='20um',
    south_gap='12um',
    cap_width='5um',
    cap_gap='6um',
    cap_gap_ground='12um',
    finger_length='55um',
    finger_count='3',
    cap_distance='1um'
))

otg9 = OpenToGround(design, 'OTG9', options=Dict(
    pos_x=f'{px-3}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg10 = OpenToGround(design, 'OTG10', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py+1])
anchors[1] = np.array([px+0,py+3.01])
anchors[2] = np.array([px+0.6,py+1])

res5 = RouteAnchors(design, 'RES5', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'CAP9',
            pin = 'north_end'
        ),
        end_pin = Dict(
            component = 'OTG10',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

line5 = RouteStraight(design, 'LINE5', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG9',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'CAP9',
            pin = 'south_end'
        )
    )
))

#########################################
#ressonador 6
px = 0
py = -6.23

otg11 = OpenToGround(design, 'OTG11', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg12 = OpenToGround(design, 'OTG12', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py-1])
anchors[1] = np.array([px+0,py-3.01])
anchors[2] = np.array([px+0.6,py-1])

res6 = RouteAnchors(design, 'RES6', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG11',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG12',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# # Hexagono versão 2

# %%
design.delete_all_components()

# %%
#ressonador 1
px1 = 0
py1 = 0

otg1 = OpenToGround(design, 'OTG1', options=Dict(
    pos_x=f'{px1-1.6}mm',
    pos_y=f'{py1}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg2 = OpenToGround(design, 'OTG2', options=Dict(
    pos_x=f'{px1+1.6}mm',
    pos_y=f'{py1}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px1-0.6,py1+1])
anchors[1] = np.array([px1+0,py1+3.01])
anchors[2] = np.array([px1+0.6,py1+1])

res1 = RouteAnchors(design, 'RES1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG1',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG2',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))
#########################################
#ressonador 2
px = 2.37
py = -0.07

otg3 = OpenToGround(design, 'OTG3', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg4 = OpenToGround(design, 'OTG4', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py-1])
anchors[1] = np.array([px+0,py-3.01])
anchors[2] = np.array([px+0.6,py-1])

res2 = RouteAnchors(design, 'RES2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG3',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG4',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))


#########################################
#ressonador 3
px = -2.37
py = -0.07

otg5 = OpenToGround(design, 'OTG5', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg6 = OpenToGround(design, 'OTG6', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py-1])
anchors[1] = np.array([px+0,py-3.01])
anchors[2] = np.array([px+0.6,py-1])

res3 = RouteAnchors(design, 'RES3', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG5',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG6',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

#########################################
#ressonador 4
px = 2.37
py = -6.16

otg7 = OpenToGround(design, 'OTG7', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg8 = OpenToGround(design, 'OTG8', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py+1])
anchors[1] = np.array([px+0,py+3.01])
anchors[2] = np.array([px+0.6,py+1])

res4 = RouteAnchors(design, 'RES4', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG7',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG8',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

#########################################
#ressonador 5
px = -2.37
py = -6.16

otg9 = OpenToGround(design, 'OTG9', options=Dict(
    pos_x=f'{px-1.6}mm',
    pos_y=f'{py}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg10 = OpenToGround(design, 'OTG10', options=Dict(
    pos_x=f'{px+1.6}mm',
    pos_y=f'{py}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px-0.6,py+1])
anchors[1] = np.array([px+0,py+3.01])
anchors[2] = np.array([px+0.6,py+1])

res5 = RouteAnchors(design, 'RES5', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG9',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG10',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

#########################################
#ressonador 6
px6 = 0
py6 = -6.23

otg11 = OpenToGround(design, 'OTG11', options=Dict(
    pos_x=f'{px6-1.6}mm',
    pos_y=f'{py6}mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg12 = OpenToGround(design, 'OTG12', options=Dict(
    pos_x=f'{px6+1.6}mm',
    pos_y=f'{py6}mm',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px6-0.6,py6-1])
anchors[1] = np.array([px6+0,py6-3.01])
anchors[2] = np.array([px6+0.6,py6-1])

res6 = RouteAnchors(design, 'RES6', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG11',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG12',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='0.5mm', end_straight='0.5mm'),
    fillet='300um',
    hfss_wire_bonds = True
))

pad1 = LaunchpadWirebond(design, 'PAD1', options=Dict(
    pos_x='-2mm',
    pos_y='4mm',
    orientation='0',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

pad2 = LaunchpadWirebond(design, 'PAD2', options=Dict(
    pos_x='2mm',
    pos_y='4mm',
    orientation='180',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px1-0.425,py1+3.01+0.5])
anchors[1] = np.array([px1,py1+3.01+0.07])
anchors[2] = np.array([px1+0.425,py1+3.01+0.5])

line1 = RouteAnchors(design, 'LINE1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'PAD1',
            pin = 'tie'
        ),
        end_pin = Dict(
            component = 'PAD2',
            pin = 'tie'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='1mm', end_straight='1mm'),
    total_length='8.5mm',
    fillet='200um',
    hfss_wire_bonds = False
))

pad3 = LaunchpadWirebond(design, 'PAD3', options=Dict(
    pos_x=f'{px6-2}mm',
    pos_y=f'{py6-3.01-1}mm',
    orientation='0',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

pad4 = LaunchpadWirebond(design, 'PAD4', options=Dict(
    pos_x=f'{px6+2}mm',
    pos_y=f'{py6-3.01-1}mm',
    orientation='180',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([px6-0.425,py6-3.01-0.5])
anchors[1] = np.array([px6,py6-3.01-0.07])
anchors[2] = np.array([px6+0.425,py6-3.01-0.5])

line2 = RouteAnchors(design, 'LINE2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'PAD3',
            pin = 'tie'
        ),
        end_pin = Dict(
            component = 'PAD4',
            pin = 'tie'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='1mm', end_straight='1mm'),
    total_length='8.5mm',
    fillet='200um',
    hfss_wire_bonds = False
))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# # Q3D

# %%
from qiskit_metal import renderers

# %%
ansys = design.renderers.q3d

# %%
ansys.connect_ansys()
# Out:
# INFO 11:36AM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:36AM [load_ansys_project]: 	Opened Ansys App
# INFO 11:36AM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.0
# INFO 11:36AM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/e196203/Documents/Ansoft/
# 	Project:   Sub redes indutivas
# INFO 11:36AM [connect_design]: 	Opened active design
# 	Design:    Capacitancias ressonador notch [Solution type: Q3D]
# INFO 11:36AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:36AM [connect]: 	Connected to project "Sub redes indutivas" and design "Capacitancias ressonador notch" 😀

# %%
ansys.activate_q3d_design('Capacitancias hexagono')
# Out:
# 11:36AM 25s WARNING [activate_q3d_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# 11:36AM 25s WARNING [activate_ansys_design]: The design_name=Capacitancias hexagono was not in active project.  Designs in active project are:
# ['Capacitancias sub rede 3 capacitiva', 'S parameter notch resonator1', 'Capacitancias sub rede 3 indutiva', 'sub rede 3 capacitiva', 'sub rede 3 indutiva', 'S parameter sub rede 3 capacitivo', 'Capacitancias two resonators', 'Capacitancias ressonador notch', 'notch resonator', 'two resonators', 'S parameter sub rede 3 indutivo', 'S parameter other 2 resonators', 'other two resonators', 'S parameter 2 notch resonators', 'S parameter two resonators', 'notch 2 resonators'].  A new design will be added to the project.
# INFO 11:36AM [connect_design]: 	Opened active design
# 	Design:    Capacitancias hexagono [Solution type: Q3D]
# WARNING 11:36AM [connect_setup]: 	No design setup detected.
# ...

# %%
ansys.clean_active_design()
ansys.render_design()

# %%
ansys.add_q3d_setup(
    name='capacitancias',
    freq_ghz=6.8,
    min_passes=2,
    max_passes=15,
    percent_error=0.2
)

# %%
ansys.analyze_setup('capacitancias')
# Out:
# INFO 01:31PM [get_setup]: 	Opened setup `capacitancias`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 01:31PM [analyze]: Analyzing setup capacitancias
# 01:50PM 44s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  CRITICAL: QEventDispatcherWin32::wakeUp: Failed to post a message (Não há cota suficiente para processar este comando.)

# %%
ansys.get_capacitance_matrix()
# Out:
# INFO 02:33PM [get_matrix]: Exporting matrix data to (D:\Users\e196203\AppData\Local\Temp\2\tmprx2378ej.txt, C, , capacitancias:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 6800000000, Maxwell, 1, False
# (                 cap_body_0_CAP5  cap_body_0_CAP8  cap_body_1_CAP5  \
#  cap_body_0_CAP5        236.86402         -0.00002         -5.97507
#  cap_body_0_CAP8         -0.00002        236.95767         -0.00005
#  cap_body_1_CAP5         -5.97507         -0.00005       1455.38476
#  cap_body_1_CAP8         -0.00013         -5.97240         -0.00143
#  g_wb                  -230.73703       -230.82456      -1435.83600
#  trace_RES1              -0.00086         -0.00038         -6.14821
#  trace_RES2              -0.00012         -0.00093         -0.00531
#  trace_RES5               0.00000         -0.00013         -6.56662
#  trace_RES6              -0.00005         -0.00049         -0.00260
#
#                   cap_body_1_CAP8        g_wb  trace_RES1  trace_RES2  \
# ...

# %% [markdown]
# # Eigenmode

# %%
ansys.disconnect_ansys()

# %%
ansys = design.renderers.hfss

# %%
ansys.connect_ansys()
# Out:
# INFO 11:00AM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:00AM [load_ansys_project]: 	Opened Ansys App
# INFO 11:00AM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.0
# INFO 11:00AM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/e196203/Documents/Ansoft/
# 	Project:   Sub redes indutivas
# INFO 11:00AM [connect_design]: 	Opened active design
# 	Design:    notch 2 resonators [Solution type: Eigenmode]
# INFO 11:00AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 11:00AM [connect]: 	Connected to project "Sub redes indutivas" and design "notch 2 resonators" 😀

# %%
ansys.activate_eigenmode_design('sub rede hexagono')
# Out:
# 11:00AM 22s WARNING [activate_eigenmode_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# INFO 11:00AM [connect_design]: 	Opened active design
# 	Design:    sub rede hexagono [Solution type: Eigenmode]

# %%
ansys.clean_active_design()
ansys.render_design(
    selection=['RES1','RES2','RES3','RES4','RES5','RES6'],
    open_pins=[('RES1','start'),('RES1','end'),('RES2','start'),('RES2','end'),('RES3','start'),('RES3','end'),('RES4','start'),('RES4','end'),('RES5','start'),('RES5','end'),('RES6','start'),('RES6','end')]
)

# %%
ansys.add_eigenmode_setup(
    name = 'ressonancias',
    n_modes = 7,
    min_passes = 15,
    max_passes = 20,
    min_converged = 2
)

# %%
ansys.activate_eigenmode_setup('ressonancias')
# Out:
# 02:55PM 48s WARNING [activate_eigenmode_setup]: This method is deprecated. Change your scripts to use activate_ansys_setup()
# INFO 02:55PM [get_setup]: 	Opened setup `ressonancias`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %%
ansys.analyze_setup('ressonancias')
# Out:
# INFO 03:46PM [get_setup]: 	Opened setup `ressonancias`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 03:46PM [analyze]: Analyzing setup ressonancias
# 04:09PM 18s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  CRITICAL: QEventDispatcherWin32::wakeUp: Failed to post a message (Não há cota suficiente para processar este comando.)

# %%
ansys.pinfo.setup.get_solutions().eigenmodes()
# Out:
# ([6.71636976349,
#   6.73748249041,
#   6.75513010759,
#   6.78966089623,
#   6.80363474037,
#   6.82767037002,
#   13.4575508748],
#  None)

# %%
ansys.plot_ansys_fields('main')
# Out:
# 04:26PM 20s WARNING [plot_ansys_fields]: This method is deprecated. Change your scripts to use plot_fields()

# %% [markdown]
# # Drivenmodal

# %%
ansys = design.renderers.hfss

# %%
ansys.connect_ansys()
# Out:
# INFO 03:11PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 03:11PM [load_ansys_project]: 	Opened Ansys App
# INFO 03:11PM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.0
# INFO 03:11PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/e196203/Documents/Ansoft/
# 	Project:   Sub redes indutivas
# INFO 03:11PM [connect_design]: 	Opened active design
# 	Design:    sub rede hexagono [Solution type: Eigenmode]
# INFO 03:11PM [get_setup]: 	Opened setup `ressonancias`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 03:11PM [connect]: 	Connected to project "Sub redes indutivas" and design "sub rede hexagono" 😀

# %%
ansys.activate_drivenmodal_design('S parameter sub rede hexagono versão 2')
# Out:
# 12:00PM 29s WARNING [activate_drivenmodal_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# INFO 12:00PM [connect_design]: 	Opened active design
# 	Design:    S parameter sub rede hexagono versão 2 [Solution type: HFSS Hybrid Modal Network]
# 12:00PM 30s WARNING [activate_ansys_design]: The design_name=S parameter sub rede hexagono versão 2 already exists, but it has solution_type==hfss hybrid modal network, which is different from the requested==drivenmodal. If you want a design with solution type==drivenmodal, please change the name requested for your design to one that does not exist. Alternatively, manually modify the solution_type for design S parameter sub rede hexagono versão 2 from the Ansys GUI.

# %%
ansys.clean_active_design()
ansys.render_design(
    selection=['RES1','RES2','RES3','RES4','RES5','RES6','LINE1','LINE2'],
    open_pins=[('RES1','start'),('RES1','end'),('RES2','start'),('RES2','end'),('RES3','start'),('RES3','end'),('RES4','start'),('RES4','end'),('RES5','start'),('RES5','end'),('RES6','start'),('RES6','end'),('LINE1','end'),('LINE2','start')],
    port_list=[('LINE1','start',50),('LINE2','end',50)]
)

# %%
ansys.add_drivenmodal_setup(
    name='Setup',
    min_passes=5,
    max_passes=7,
    min_converged=5,
    max_delta_s=0.02,
    basis_order=-1
)
