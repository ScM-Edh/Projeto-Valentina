# %%
# %load_ext autoreload
# %autoreload 2

import qiskit_metal as metal
from qiskit_metal import Dict, designs, MetalGUI

# %%
from qiskit_metal.qlibrary.tlines.framed_path import RouteFramed
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
import numpy as np
from collections import OrderedDict
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
from qiskit_metal.qlibrary.tlines.framed_path import RouteFramed
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal . qlibrary . tlines . pathfinder import RoutePathfinder
from qiskit_metal . qlibrary . tlines . meandered import RouteMeander

# %%
design = designs.DesignPlanar(overwrite_enabled=True)

# %%
gui = MetalGUI(design)

# %%
design.variables['cpw_width']='20um'
design.variables['cpw_gap']='12um'

# %% [markdown]
# # Um ressonador com acoplamento indutivo em linha

# %%
otg1 = OpenToGround(design, 'OTG1', options=Dict(
    pos_x='-4.25mm',
    pos_y='0',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg2 = OpenToGround(design, 'OTG2', options=Dict(
    pos_x='4.25mm',
    pos_y='0',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

res = RouteStraight(design, 'RES', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG1',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG2',
            pin = 'open'
        )
    ),
    hfss_wire_bonds = True
))

otg3 = OpenToGround(design, 'OTG3', options=Dict(
    pos_x='-3.42mm',
    pos_y='70um',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg4 = OpenToGround(design, 'OTG4', options=Dict(
    pos_x='3.42mm',
    pos_y='-70um',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

pad1 = LaunchpadWirebond(design, 'PAD1', options=Dict(
    pos_x='-5mm',
    pos_y='70um',
    orientation='0',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

pad2 = LaunchpadWirebond(design, 'PAD2', options=Dict(
    pos_x='5mm',
    pos_y='-70um',
    orientation='180',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

line1 = RouteStraight(design, 'LINE1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG3',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD1',
            pin = 'tie'
        )
    )
))

line2 = RouteStraight(design, 'LINE2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG4',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD2',
            pin = 'tie'
        )
    )
))


gui.rebuild()
gui.autoscale()

# %% [markdown]
# # Um ressonador com acoplamento indutivo em U

# %%
design.delete_all_components()

# %%
otg1 = OpenToGround(design, 'OTG1', options=Dict(
    pos_x='-1mm',
    pos_y='0',
    orientation='-90',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg2 = OpenToGround(design, 'OTG2', options=Dict(
    pos_x='1mm',
    pos_y='0',
    orientation='-90',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

res = RoutePathfinder(design, 'RES', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG1',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG2',
            pin = 'open'
        )
    ),
    lead=Dict(start_straight='3.55mm', end_straight='3.55mm'),
    total_length='8.5mm',
    fillet='700um',
    #hfss_wire_bonds = True
))

otg3 = OpenToGround(design, 'OTG3', options=Dict(
    pos_x='-1.07mm',
    pos_y='830um',
    orientation='90',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg4 = OpenToGround(design, 'OTG4', options=Dict(
    pos_x='1.07mm',
    pos_y='830um',
    orientation='90',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

pad1 = LaunchpadWirebond(design, 'PAD1', options=Dict(
    pos_x='-1.07mm',
    pos_y='-1mm',
    orientation='90',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

pad2 = LaunchpadWirebond(design, 'PAD2', options=Dict(
    pos_x='1.07mm',
    pos_y='-1mm',
    orientation='90',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

line1 = RouteStraight(design, 'LINE1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG3',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD1',
            pin = 'tie'
        )
    )
))

line2 = RouteStraight(design, 'LINE2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG4',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD2',
            pin = 'tie'
        )
    )
))


gui.rebuild()
gui.autoscale()

# %% [markdown]
# # Modelo 3

# %%
design.delete_all_components()

# %%
otg1 = OpenToGround(design, 'OTG1', options=Dict(
    pos_x='-2.5mm',
    pos_y='0',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg2 = OpenToGround(design, 'OTG2', options=Dict(
    pos_x='2.5mm',
    pos_y='0',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

from collections import OrderedDict
anchors = OrderedDict()
anchors[0] = np.array([-1,1])
anchors[1] = np.array([0,2.18])
anchors[2] = np.array([1,1])

res = RouteAnchors(design, 'RES', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG1',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'OTG2',
            pin = 'open'
        )
    ),
    anchors = anchors,
    lead=Dict(start_straight='1mm', end_straight='1mm'),
    total_length='8.5mm',
    fillet='500um',
    hfss_wire_bonds = True
))

otg3 = OpenToGround(design, 'OTG3', options=Dict(
    pos_x='-1.67mm',
    pos_y='-70um',
    orientation='0',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

otg4 = OpenToGround(design, 'OTG4', options=Dict(
    pos_x='1.67mm',
    pos_y='-70um',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

pad1 = LaunchpadWirebond(design, 'PAD1', options=Dict(
    pos_x='-3mm',
    pos_y='-70um',
    orientation='0',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

pad2 = LaunchpadWirebond(design, 'PAD2', options=Dict(
    pos_x='3mm',
    pos_y='-70um',
    orientation='180',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

line1 = RouteStraight(design, 'LINE1', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG3',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD1',
            pin = 'tie'
        )
    )
))

line2 = RouteStraight(design, 'LINE2', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG4',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD2',
            pin = 'tie'
        )
    )
))

otg5 = OpenToGround(design, 'OTG5', options=Dict(
    pos_x='-415um',
    pos_y='2.25mm',
    orientation='180',
    width='20um',
    gap='12um',
    termination_gap='12um'
))

pad3 = LaunchpadWirebond(design, 'PAD3', options=Dict(
    pos_x='435um',
    pos_y='3.5mm',
    orientation='-90',
    lead_length='25um',
    pad_width='350um',
    pad_height='350um',
    pad_gap='150um',
    taper_height='370um'
))

line3 = RouteFramed(design, 'LINE3', options=Dict(
    pin_inputs = Dict(
        start_pin = Dict(
            component = 'OTG5',
            pin = 'open'
        ),
        end_pin = Dict(
            component = 'PAD3',
            pin = 'tie'
        )
    ),
    fillet='200um'
))


gui.rebuild()
gui.autoscale()
# Out:
# INFO 10:58AM [__del__]: Disconnected from Ansys HFSS
# INFO 10:58AM [__del__]: Disconnected from Ansys HFSS

# %% [markdown]
# # Q3D

# %%
ansys.disconnect_ansys()

# %%
from qiskit_metal import renderers

# %%
ansys = design.renderers.q3d

# %%
ansys.connect_ansys()
# Out:
# INFO 07:36PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 07:36PM [load_ansys_project]: 	Opened Ansys App
# INFO 07:36PM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.0
# INFO 07:36PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/e196203/Desktop/Simulações/qiskit metal/Inductive couplers/
# 	Project:   Ressonador com acoplamento indutivo
# INFO 07:36PM [connect_design]: 	Opened active design
# 	Design:    Capacitancias formato em U [Solution type: Q3D]
# INFO 07:36PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 07:36PM [connect]: 	Connected to project "Ressonador com acoplamento indutivo" and design "Capacitancias formato em U" 😀

# %%
ansys.activate_q3d_design('Capacitancias modelo teste 3')
# Out:
# 07:36PM 54s WARNING [activate_q3d_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# 07:36PM 54s WARNING [activate_ansys_design]: The design_name=Capacitancias modelo teste 3 was not in active project.  Designs in active project are:
# ['S parameter', 'ressonador formato em U', 'Capacitancias formato em U', 'Capacitancias', 'ressonador'].  A new design will be added to the project.
# INFO 07:36PM [connect_design]: 	Opened active design
# 	Design:    Capacitancias modelo teste 3 [Solution type: Q3D]
# WARNING 07:36PM [connect_setup]: 	No design setup detected.
# WARNING 07:36PM [connect_setup]: 	Creating Q3D default setup.
# INFO 07:36PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)

# %%
ansys.clean_active_design()
ansys.render_design()

# %%
ansys.add_q3d_setup(
    name='capacitancias',
    freq_ghz=7,
    min_passes=2,
    max_passes=15,
    percent_error=0.2
)

# %%
ansys.analyze_setup('capacitancias')
# Out:
# INFO 07:37PM [get_setup]: 	Opened setup `capacitancias`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 07:37PM [analyze]: Analyzing setup capacitancias

# %%
ansys.get_capacitance_matrix()
# Out:
# INFO 07:41PM [get_matrix]: Exporting matrix data to (D:\Users\e196203\AppData\Local\Temp\5\tmp6_5tr1n6.txt, C, , capacitancias:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 7000000000, Maxwell, 1, False
# (                   ground_main_plane  launch_pad_PAD1  launch_pad_PAD2  \
#  ground_main_plane         2951.44492       -383.87630       -383.92890
#  launch_pad_PAD1           -383.87630        393.85262         -0.01857
#  launch_pad_PAD2           -383.92890         -0.01857        393.89953
#  launch_pad_PAD3           -470.90469         -0.01151         -0.01511
#  trace_RES                -1421.51804         -6.92348         -6.92206
#
#                     launch_pad_PAD3   trace_RES
#  ground_main_plane       -470.90469 -1421.51804
#  launch_pad_PAD1           -0.01151    -6.92348
#  launch_pad_PAD2           -0.01511    -6.92206
#  launch_pad_PAD3          479.32503    -6.43035
#  trace_RES                 -6.43035  1442.86687  ,
#  'fF')

# %% [markdown]
# # Eigenmode

# %%
ansys.disconnect_ansys()

# %%
ansys = design.renderers.hfss

# %%
ansys.connect_ansys()
# Out:
# INFO 07:42PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 07:42PM [load_ansys_project]: 	Opened Ansys App
# INFO 07:42PM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.0
# INFO 07:42PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/e196203/Desktop/Simulações/qiskit metal/Inductive couplers/
# 	Project:   Ressonador com acoplamento indutivo
# INFO 07:42PM [connect_design]: 	Opened active design
# 	Design:    Capacitancias modelo teste 3 [Solution type: Q3D]
# INFO 07:42PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 07:42PM [connect]: 	Connected to project "Ressonador com acoplamento indutivo" and design "Capacitancias modelo teste 3" 😀

# %%
ansys.activate_eigenmode_design('ressonador modelo teste 3')
# Out:
# 07:43PM 11s WARNING [activate_eigenmode_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# 07:43PM 11s WARNING [activate_ansys_design]: The design_name=ressonador modelo teste 3 was not in active project.  Designs in active project are:
# ['S parameter', 'ressonador formato em U', 'Capacitancias formato em U', 'Capacitancias', 'ressonador', 'Capacitancias modelo teste 3'].  A new design will be added to the project.
# INFO 07:43PM [connect_design]: 	Opened active design
# 	Design:    ressonador modelo teste 3 [Solution type: Eigenmode]
# WARNING 07:43PM [connect_setup]: 	No design setup detected.
# WARNING 07:43PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 07:43PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %%
ansys.clean_active_design()
ansys.render_design(selection=['RES','LINE1','LINE2','LINE3','PAD1','PAD2','PAD3'],
                    open_pins=[('RES','start'),('RES','end'),('LINE1','start'),('LINE2','start'),('LINE3','start')])

# %%
ansys.add_eigenmode_setup(
    name = 'ressonancias_2',
    n_modes = 4,
    min_passes = 15,
    max_passes = 20,
    min_converged = 2
)

# %%
ansys.activate_eigenmode_setup('ressonancias_2')
# Out:
# 11:10AM 40s WARNING [activate_eigenmode_setup]: This method is deprecated. Change your scripts to use activate_ansys_setup()
# INFO 11:10AM [get_setup]: 	Opened setup `ressonancias_2`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %%
ansys.analyze_setup('ressonancias_2')
# Out:
# INFO 12:05PM [get_setup]: 	Opened setup `ressonancias_2`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:05PM [analyze]: Analyzing setup ressonancias_2

# %%
ansys.pinfo.setup.get_solutions().eigenmodes()
# Out:
# ([6.91102203875, 13.8751957267, 18.2597325548, 19.4382581269], None)

# %%
ansys.plot_ansys_fields('main')
# Out:
# 12:21PM 15s WARNING [plot_ansys_fields]: This method is deprecated. Change your scripts to use plot_fields()

# %% [markdown]
# # Drivenmode

# %%
ansys = design.renderers.hfss

# %%
ansys.connect_ansys()

# %%
ansys.activate_drivenmodal_design('S parameter model 4')
# Out:
# 12:22PM 48s WARNING [activate_drivenmodal_design]: This method is deprecated. Change your scripts to use activate_ansys_design()
# INFO 12:22PM [connect_design]: 	Opened active design
# 	Design:    S parameter model 4 [Solution type: HFSS Hybrid Modal Network]
# 12:22PM 48s WARNING [activate_ansys_design]: The design_name=S parameter model 4 already exists, but it has solution_type==hfss hybrid modal network, which is different from the requested==drivenmodal. If you want a design with solution type==drivenmodal, please change the name requested for your design to one that does not exist. Alternatively, manually modify the solution_type for design S parameter model 4 from the Ansys GUI.

# %%
ansys.clean_active_design()
ansys.render_design(
    selection=['RES','LINE1','LINE2','LINE3'],
    open_pins=[('RES','start'),('RES','end'),('LINE1','start'),('LINE2','start'),('LINE3','start')],
    port_list=[('LINE1','end',50),('LINE2','end',50),('LINE3','end',50)]
)

# %%
ansys.add_drivenmodal_setup(
    name='Setup',
    min_passes=22,
    max_passes=25,
    min_converged=5,
    max_delta_s=0.002,
    basis_order=-1
)

# %%
gui.main_window.close()
# Out:
# True
